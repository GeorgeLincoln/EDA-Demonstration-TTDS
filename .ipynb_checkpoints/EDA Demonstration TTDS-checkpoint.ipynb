# %% [markdown]
# <center><h1>Análise Exploratória de Dados com Python e Pandas</h1></center>
# <center><h3>Demonstração com o dataset *Titanic: Machine Learning from Disaster* (kaggle.com)</h3><center>

# %% [markdown]
# ![title](static/youtube.jpg)
# <center>Figura 1: TITANIC sinking. Extraída de https://youtu.be/9xoqXVjBEF8</center>

# %% [markdown]
# <h2 style="color:#4682B4">Análise Exploratória de Dados (AED) ou Exploratory data analysis(EDA)</h2>
#
# Objetivos:
# <ul>
# <li>Examinar dados previamente à aplicação de qualquer técnica.</li>
# <li>Realizar uma análise descritiva dos dados, de modo a se ter um entendimento básico dos dados e das relalações existentes entre as variáveis analisadas</li>
# </ul>
#
# <h3 style="color:#4682B4">Etapas da AED:</h3>
# <ul>
# <li>Preparação dos Dados para serem acessíveis a qualquer técnica</li>
# <li>Exame Gráfico da natureza das Variáveis Individuais</li>
# <li>Exame Gráfico das relações entre as variáveis analisadas</li>
# <li>Identificar possíveis atípicos / anomalias / *outliers*</li>
# <li>Verificar se existem dados ausentes (*missing*)</li>
# <li> Verificar suposições sobre os dados, como normalidade, linearidade, etc.</li>
# </ul>

# %% [markdown]
# ![title](static/kagglettnc.jpg)
# <center>Figura 1: Dataset Titanic. Disponível em https://www.kaggle.com/c/titanic/data</center>
#
# - Conjuntos de Dados:
#     - Treinamento: 891 exemplos rotulados
#     - Teste: 418 exemplos não rotulados
#
#
# - Atributos:
#     - **Survival**
#     - **Pclass**: Categoria do Ticket. Uma representação para o *status* socio-econômico. 1st - Upper, 2nd - Middle, 3rd - Lower
#     - **Sex**: Sexo.
#     - **Age**: Idade em anos.
#     - **Sibsp**: # número de irmãos / cônjuges a bordo.
#     * **Parch**: # de parentes / crianças a bordo.
#     - **Ticket**: Número do Ticket.
#     - **Fare**: Tarifa de passageiros.
#     - **Cabin**: Número da cabine.
#     - **Embarked**: Porto de embarcação - C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# ## Demonstração com Pandas
#
# ![title](static/pandas.jpg)

# %%
### Módulos necessários
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### I Analisar os Dados de Treinamento

# %% [markdown]
# #### A. Explorar os dados
# - Verificar o tipo de dados de cada coluna (variável categórica, numérica, etc.)
# - Observar min/max/média dos valores

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
# Arquivos disponíveis em https://www.kaggle.com/c/titanic/data

# DataFrame com o conjunto de treinamento
train = pd.read_csv('data/train.csv')

# Dataframe com o conjunto de teste
test = pd.read_csv('data/test.csv')

# %%
# DataFrame: Uma coleção de Séries, onde cada série pode ter um tipo diferente.
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Algo bem simples: Deixar as letras em maiúsculas
train.Name.map(lambda name: name.upper())
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
# 5                                       MORAN, MR. JAMES
# 6                                MCCARTHY, MR. TIMOTHY J
# 7                         PALSSON, MASTER. GOSTA LEONARD
# 8      JOHNSON, MRS. OSCAR W (ELISABETH VILHELMINA BERG)
# 9                    NASSER, MRS. NICHOLAS (ADELE ACHEM)
# 10                       SANDSTROM, MISS. MARGUERITE RUT
# 11                              BONNELL, MISS. ELIZABETH
# 12                        SAUNDERCOCK, MR. WILLIAM HENRY
# 13                           ANDERSSON, MR. ANDERS JOHAN
# 14                  VESTROM, MISS. HULDA AMANDA ADOLFINA
# 15                      HEWLETT, MRS. (MARY D KINGCOME)
# 16                                  RICE, MASTER. EUGENE
# 17                          WILLIAMS, MR. CHARLES EUGENE
# 18     VANDER PLANKE, MRS. JULIUS (EMELIA MARIA VANDE...
# 19                               MASSELMANI, MRS. FATIMA
# 20                                  FYNNEY, MR. JOSEPH J
# 21                                 BEESLEY, MR. LAWRENCE
# 22                           MCGOWAN, MISS. ANNA "ANNIE"
# 23                          SLOPER, MR. WILLIAM THOMPSON
# 24                         PALSSON, MISS. TORBORG DANIRA
# 25     ASPLUND, MRS. CARL OSCAR (SELMA AUGUSTA EMILIA...
# 26                               EMIR, MR. FARRED CHEHAB
# 27                        FORTUNE, MR. CHARLES ALEXANDER
# 28                         O'DWYER, MISS. ELLEN "NELLIE"
# 29                                   TODOROFF, MR. LALIO
#                              ...
# 861                          GILES, MR. FREDERICK EDWARD
# 862    SWIFT, MRS. FREDERICK JOEL (MARGARET WELLES BA...
# 863                    SAGE, MISS. DOROTHY EDITH "DOLLY"
# 864                               GILL, MR. JOHN WILLIAM
# 865                             BYSTROM, MRS. (KAROLINA)
# 866                         DURAN Y MORE, MISS. ASUNCION
# 867                 ROEBLING, MR. WASHINGTON AUGUSTUS II
# 868                          VAN MELKEBEKE, MR. PHILEMON
# 869                      JOHNSON, MASTER. HAROLD THEODOR
# 870                                    BALKIC, MR. CERIN
# 871     BECKWITH, MRS. RICHARD LEONARD (SALLIE MONYPENY)
# 872                             CARLSSON, MR. FRANS OLOF
# 873                          VANDER CRUYSSEN, MR. VICTOR
# 874                ABELSON, MRS. SAMUEL (HANNAH WIZOSKY)
# 875                     NAJIB, MISS. ADELE KIAMIE "JANE"
# 876                        GUSTAFSSON, MR. ALFRED OSSIAN
# 877                                 PETROFF, MR. NEDELIO
# 878                                   LALEFF, MR. KRISTO
# 879        POTTER, MRS. THOMAS JR (LILY ALEXENIA WILSON)
# 880         SHELLEY, MRS. WILLIAM (IMANITA PARRISH HALL)
# 881                                   MARKUN, MR. JOHANN
# 882                         DAHLBERG, MISS. GERDA ULRIKA
# 883                        BANFIELD, MR. FREDERICK JAMES
# 884                               SUTEHALL, MR. HENRY JR
# 885                 RICE, MRS. WILLIAM (MARGARET NORTON)
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
# dimensões da matriz
rows, columns = train.shape

rows, columns
# Out:
# (891, 12)

# %%
# Quantidade de exemplos em cada classe - Survived: 0 ou 1
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# Esta é uma variável contínua
train.Fare.value_counts().head(10)
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 26.5500    15
# 0.0000     15
# Name: Fare, dtype: int64

# %%
# estatísticas sobre esta coluna
train.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# Correlação entre as variáveis
train.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# #### B. Verificar se há valores nulos nas Colunas
#
# ![title](static/missingdata.jpg)
# <center>[Link da Imagem](https://www.maxpixel.net/Exact-Fit-Piece-Puzzle-Last-Particles-Demarcation-654957)</center>

# %%
# Colunas (Features)# Colunas 
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# valores nulos para o atributo Sex ?
train.Sex.isnull().sum()
# Out:
# 0

# %%
# valores nulos para o atributo PClass ?
train.Pclass.isnull().sum()
# Out:
# 0

# %%
# valores nulos para o atributo Fare ?
train.Fare.isnull().sum()
# Out:
# 0

# %%
# valores nulos para o atributo Age ?
# há 177 linhas com valores NaN para a coluna 'Age'
train.Age.isnull().sum()
# Out:
# 177

# %%
# valores nulos para o atributo Embarked ?
# há 2 linhas com valores NaN para a coluna 'Embarked'
train.Embarked.isnull().sum()
# Out:
# 2

# %%
# Observe que Sex é um atributo categórico
train.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# Cria um novo atributo
train['FamilySize'] = train.SibSp + train.Parch

# %% [markdown]
# #### C Preencher valores Faltantes
#
#
# ![title](static/fillingdata.jpg)
# <center>[Link da Imagem](https://www.maxpixel.net/Exact-Fit-Piece-Puzzle-Last-Particles-Demarcation-654957)</center>

# %%
# preenche valores Age NaN com a mediana de idade
train.Age = train.Age.fillna(train.Age.median()) # preenche valores NaN

train.Age.isnull().sum()
# Out:
# 0

# %%
#train.Embarked.fillna(train.Embarked.)
train.Embarked = train.Embarked.fillna(train.Embarked.value_counts().index[0]) # preenche valores NaN

train.Embarked.isnull().sum()
# Out:
# 0

# %% [markdown]
# #### D. Realizar Consultas para obter Insights Úteis a partir dos Dados

# %%
# filtrando os dados ..
train[ train.Sex == 'female'].head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# 3      0            113803  53.1000  C123        S           1

# %%
# Não há campos nulos nesta coluna
train [train.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, FamilySize]
# Index: []

# %%
train[train.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, FamilySize]
# Index: []

# %% [markdown]
# #### E. Transformar Dados Categóricos em Dados Numéricos

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
train.Sex = encoder.fit_transform(train.Sex.values)

# %%
# transformar dados categóricos em numéricos
# usa variáveis dummy
dummies_embarked = pd.get_dummies(train.Embarked)
train['C'] = dummies_embarked.C
train['Q'] = dummies_embarked.Q
train['S'] = dummies_embarked.S
train = train.drop('Embarked', axis=1)
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
#
#              Ticket     Fare Cabin  FamilySize  C  Q  S
# 0         A/5 21171   7.2500   NaN           1  0  0  1
# 1          PC 17599  71.2833   C85           1  1  0  0
# 2  STON/O2. 3101282   7.9250   NaN           0  0  0  1

# %% [markdown]
# #### F. Visualizar Dados
# - alguma informação sobre a distribuição dos dados ?

# %%
pd.plotting.scatter_matrix(train[['Fare', 'Age']], figsize=(6,6))
plt.show()

# %%
# Scatter plot
from matplotlib import pyplot as plt
plt.scatter(train.Fare, train.Age)
plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Fare vs Age')

# %%
# Scatter plot
from matplotlib import pyplot as plt
plt.scatter(train[train.Survived==0].Fare, train[train.Survived==0].Age, c='red')
plt.scatter(train[train.Survived==1].Fare, train[train.Survived==1].Age, c='green')
plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Fare vs Age')

# %%
import seaborn as sb
sb.pairplot(train, hue = 'Survived')

# %%
# Correlação entre as variáveis
plt.matshow(train.corr())

# %%
# Plote esta série de dados
train.Sex.value_counts().plot(kind='bar')

# %%
# Plote esta série de dados
train.FamilySize.value_counts().plot(kind='bar')

# %%
# Plote esta série de dados, mas desconsidere os valores nulos
train.FamilySize.dropna().value_counts().plot(kind='bar')

# %%
# Histograma desta coluna
train.Fare.hist()

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  FamilySize  C  Q  S
# 0         A/5 21171   7.2500   NaN           1  0  0  1
# 1          PC 17599  71.2833   C85           1  1  0  0
# 2  STON/O2. 3101282   7.9250   NaN           0  0  0  1
# 3            113803  53.1000  C123           1  0  0  1
# 4            373450   8.0500   NaN           0  0  0  1

# %%
# sobreviventes# sobrevi 
fig, axis = plt.subplots(1,2)
train[train.Sex==1].Survived.value_counts().plot(kind='barh', title='Male Survivorship', ax=axis[0])
train[train.Sex==0].Survived.value_counts().plot(kind='barh',  title='Female Survivorship', ax=axis[1])

# %%
train.groupby(['Sex', 'Survived']).size().unstack().plot(kind='bar').set_title('Gender Histogram Training Data')

# %%
# Crianças
train[ train.Age < 12 ].Survived.value_counts().plot(kind='barh')

# %%
# mulheres e crianças
train[ (train.Age < 12) | (train.Sex==0) ].Survived.value_counts().plot(kind='barh')

# %%
# Classe vs Idade
import seaborn as sb
facet = sb.FacetGrid(train, hue='Survived', aspect=4)
facet.map(sb.kdeplot, 'Age', shade=True)
facet.set(xlim=(0, train.Age.max()))
facet.add_legend()

# %% [markdown]
# ## II Analisar os Dados de Teste

# %% [markdown]
# ### Verificar se há valores nulos nas Colunas

# %%
test.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
# valores nulos para o atributo Sex ?
test.Sex.isnull().sum()
# Out:
# 0

# %%
# valores nulos para o atributo Age ?# valores 
test.Fare.isnull().sum()
# Out:
# 1

# %%
# valores nulos para o atributo Cabin ?
test.Cabin.isnull().sum()
# Out:
# 327

# %%
# valores nulos para o atributo Fare ?# valores 
test.Fare.isnull().sum()
# Out:
# 1

# %% [markdown]
# ### Preencher valores Faltantes

# %%
# Localizar linhas com valores nulos ...
test [test.Fare.isnull()]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked
# 152   NaN   NaN        S

# %%
# altera valor
test.loc[test.PassengerId==1044, 'Fare'] = train[train.Sex==1].Fare.mean()

# %% [markdown]
# ####  Transformar Dados Categóricos em Dados Numéricos

# %%
# transformar dados categóricos em numéricos
dummies = pd.get_dummies(test.Embarked)
test['C'] = dummies.C
test['Q'] = dummies.Q
test['S'] = dummies.S
test = test.drop('Embarked', axis=1)
test.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin  C  Q  S
# 0      0  330911  7.8292   NaN  0  1  0
# 1      0  363272  7.0000   NaN  0  0  1
# 2      0  240276  9.6875   NaN  0  1  0

# %%
encoder = LabelEncoder()
test.Sex = encoder.fit_transform(test.Sex.values)

test.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Cabin  C  Q  S
# 0  34.5      0      0   330911   7.8292   NaN  0  1  0
# 1  47.0      1      0   363272   7.0000   NaN  0  0  1
# 2  62.0      0      0   240276   9.6875   NaN  0  1  0
# 3  27.0      0      0   315154   8.6625   NaN  0  0  1
# 4  22.0      1      1  3101298  12.2875   NaN  0  0  1

# %%
# Conjunto de teste
X_test = test[[ 'PassengerId', 'Fare', 'Sex']].values

# %%
X_test
# Out:
# array([[8.92000e+02, 7.82920e+00, 1.00000e+00],
#        [8.93000e+02, 7.00000e+00, 0.00000e+00],
#        [8.94000e+02, 9.68750e+00, 1.00000e+00],
#        ...,
#        [1.30700e+03, 7.25000e+00, 1.00000e+00],
#        [1.30800e+03, 8.05000e+00, 1.00000e+00],
#        [1.30900e+03, 2.23583e+01, 1.00000e+00]])

# %% [markdown]
# ## III C Classificação Supervisionada com Sklearn
#
# ![title](static/sklearn.jpg)

# %% [markdown]
# **O Teorema de Bayes**
#
# $
# \Large
# P(c | x) = \frac{P(x | c) \cdot P(c)}{P(x)}
# $
#
# onde:
#  - P(c): Probabilidade a priori da classe
#  - P(x): Probabilidade a priori do exemplo
#  - P(c | x): Probabilidade a posteriori da classe dado um exemplo
#  - P(x | c): Probabilidade do exemplo dada a classe
#
# Suposição da indeipendência dos dados:
#
# $
# \Large
# P(x | c) = P(x_1 | c) \cdot P(x_2 | c) \cdot \ldots P(x_n | c)
# $
#
#
# Logo:
#
# $
# \Large
# P(c | x) = P(x | c) = P(x_1 | c) \cdot P(x_2 | c) \cdot \ldots P(x_n | c) \cdot P(c)
# $

# %%
# Exemplos para o Conjunto de Treinamento
X = train[[ 'Fare', 'Sex']].values

# Classe de cada exemplo de treinamento
y = train['Survived'].values

# %%
# Classificação supervisionada com skLearn# Classif 
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
model = classifier.fit(X, y)

# %%
predictions = model.predict(X_test[:, 1:])
passengers = test.PassengerId

# %%
file = open('submission.csv', 'w')
file.write('PassengerId,Survived\n')
for prediction, passenger  in zip(predictions, passengers):
    print('{}\t\t{}\n'.format(passenger, 'died' if prediction == 0 else 'survived'))
    file.write('{},{}\n'.format(passenger, prediction))
file.close()
# Out:
# 892		died
#
# 893		survived
#
# 894		died
#
# 895		died
#
# 896		survived
#
# 897		died
#
# 898		survived
#
# 899		died
#
# 900		survived
#
# 901		died
#
# 902		died
#
# 903		died
#
# 904		survived
#
# 905		died
#
# 906		survived
#
# 907		survived
#
# 908		died
#
# 909		died
#
# 910		survived
#
# 911		survived
#
# 912		died
#
# 913		died
#
# 914		survived
#
# 915		died
#
# 916		survived
#
# 917		died
#
# 918		survived
#
# 919		died
#
# 920		died
#
# 921		died
#
# 922		died
#
# 923		died
#
# 924		survived
#
# 925		survived
#
# 926		died
#
# 927		died
#
# 928		survived
#
# 929		survived
#
# 930		died
#
# 931		died
#
# 932		died
#
# 933		died
#
# 934		died
#
# 935		survived
#
# 936		survived
#
# 937		died
#
# 938		died
#
# 939		died
#
# 940		survived
#
# 941		survived
#
# 942		died
#
# 943		died
#
# 944		survived
#
# 945		survived
#
# 946		died
#
# 947		died
#
# 948		died
#
# 949		died
#
# 950		died
#
# 951		survived
#
# 952		died
#
# 953		died
#
# 954		died
#
# 955		survived
#
# 956		survived
#
# 957		survived
#
# 958		survived
#
# 959		died
#
# 960		died
#
# 961		survived
#
# 962		survived
#
# 963		died
#
# 964		survived
#
# 965		died
#
# 966		survived
#
# 967		survived
#
# 968		died
#
# 969		survived
#
# 970		died
#
# 971		survived
#
# 972		died
#
# 973		survived
#
# 974		died
#
# 975		died
#
# 976		died
#
# 977		died
#
# 978		survived
#
# 979		survived
#
# 980		survived
#
# 981		died
#
# 982		survived
#
# 983		died
#
# 984		survived
#
# 985		died
#
# 986		died
#
# 987		died
#
# 988		survived
#
# 989		died
#
# 990		survived
#
# 991		died
#
# 992		survived
#
# 993		died
#
# 994		died
#
# 995		died
#
# 996		survived
#
# 997		died
#
# 998		died
#
# 999		died
#
# 1000		died
#
# 1001		died
#
# 1002		died
#
# 1003		survived
#
# 1004		survived
#
# 1005		survived
#
# 1006		survived
#
# 1007		died
#
# 1008		died
#
# 1009		survived
#
# 1010		died
#
# 1011		survived
#
# 1012		survived
#
# 1013		died
#
# 1014		survived
#
# 1015		died
#
# 1016		died
#
# 1017		survived
#
# 1018		died
#
# 1019		survived
#
# 1020		died
#
# 1021		died
#
# 1022		died
#
# 1023		died
#
# 1024		survived
#
# 1025		died
#
# 1026		died
#
# 1027		died
#
# 1028		died
#
# 1029		died
#
# 1030		survived
#
# 1031		died
#
# 1032		survived
#
# 1033		survived
#
# 1034		survived
#
# 1035		died
#
# 1036		died
#
# 1037		died
#
# 1038		died
#
# 1039		died
#
# 1040		died
#
# 1041		died
#
# 1042		survived
#
# 1043		died
#
# 1044		died
#
# 1045		survived
#
# 1046		died
#
# 1047		died
#
# 1048		survived
#
# 1049		survived
#
# 1050		died
#
# 1051		survived
#
# 1052		survived
#
# 1053		died
#
# 1054		survived
#
# 1055		died
#
# 1056		died
#
# 1057		survived
#
# 1058		died
#
# 1059		died
#
# 1060		survived
#
# 1061		survived
#
# 1062		died
#
# 1063		died
#
# 1064		died
#
# 1065		died
#
# 1066		died
#
# 1067		survived
#
# 1068		survived
#
# 1069		died
#
# 1070		survived
#
# 1071		survived
#
# 1072		died
#
# 1073		died
#
# 1074		survived
#
# 1075		died
#
# 1076		survived
#
# 1077		died
#
# 1078		survived
#
# 1079		died
#
# 1080		survived
#
# 1081		died
#
# 1082		died
#
# 1083		died
#
# 1084		died
#
# 1085		died
#
# 1086		died
#
# 1087		died
#
# 1088		survived
#
# 1089		survived
#
# 1090		died
#
# 1091		survived
#
# 1092		survived
#
# 1093		died
#
# 1094		survived
#
# 1095		survived
#
# 1096		died
#
# 1097		died
#
# 1098		survived
#
# 1099		died
#
# 1100		survived
#
# 1101		died
#
# 1102		died
#
# 1103		died
#
# 1104		died
#
# 1105		survived
#
# 1106		survived
#
# 1107		died
#
# 1108		survived
#
# 1109		survived
#
# 1110		survived
#
# 1111		died
#
# 1112		survived
#
# 1113		died
#
# 1114		survived
#
# 1115		died
#
# 1116		survived
#
# 1117		survived
#
# 1118		died
#
# 1119		survived
#
# 1120		died
#
# 1121		died
#
# 1122		died
#
# 1123		survived
#
# 1124		died
#
# 1125		died
#
# 1126		died
#
# 1127		died
#
# 1128		died
#
# 1129		died
#
# 1130		survived
#
# 1131		survived
#
# 1132		survived
#
# 1133		survived
#
# 1134		survived
#
# 1135		died
#
# 1136		died
#
# 1137		died
#
# 1138		survived
#
# 1139		died
#
# 1140		survived
#
# 1141		survived
#
# 1142		survived
#
# 1143		died
#
# 1144		survived
#
# 1145		died
#
# 1146		died
#
# 1147		died
#
# 1148		died
#
# 1149		died
#
# 1150		survived
#
# 1151		died
#
# 1152		died
#
# 1153		died
#
# 1154		survived
#
# 1155		survived
#
# 1156		died
#
# 1157		died
#
# 1158		died
#
# 1159		died
#
# 1160		survived
#
# 1161		died
#
# 1162		died
#
# 1163		died
#
# 1164		survived
#
# 1165		survived
#
# 1166		died
#
# 1167		survived
#
# 1168		died
#
# 1169		died
#
# 1170		died
#
# 1171		died
#
# 1172		survived
#
# 1173		died
#
# 1174		survived
#
# 1175		survived
#
# 1176		survived
#
# 1177		died
#
# 1178		died
#
# 1179		died
#
# 1180		died
#
# 1181		died
#
# 1182		died
#
# 1183		survived
#
# 1184		died
#
# 1185		died
#
# 1186		died
#
# 1187		died
#
# 1188		survived
#
# 1189		died
#
# 1190		died
#
# 1191		died
#
# 1192		died
#
# 1193		died
#
# 1194		died
#
# 1195		died
#
# 1196		survived
#
# 1197		survived
#
# 1198		survived
#
# 1199		died
#
# 1200		died
#
# 1201		survived
#
# 1202		died
#
# 1203		died
#
# 1204		died
#
# 1205		survived
#
# 1206		survived
#
# 1207		survived
#
# 1208		survived
#
# 1209		died
#
# 1210		died
#
# 1211		died
#
# 1212		died
#
# 1213		died
#
# 1214		died
#
# 1215		died
#
# 1216		survived
#
# 1217		died
#
# 1218		survived
#
# 1219		died
#
# 1220		died
#
# 1221		died
#
# 1222		survived
#
# 1223		died
#
# 1224		died
#
# 1225		survived
#
# 1226		died
#
# 1227		died
#
# 1228		died
#
# 1229		died
#
# 1230		died
#
# 1231		died
#
# 1232		died
#
# 1233		died
#
# 1234		died
#
# 1235		survived
#
# 1236		died
#
# 1237		survived
#
# 1238		died
#
# 1239		survived
#
# 1240		died
#
# 1241		survived
#
# 1242		survived
#
# 1243		died
#
# 1244		died
#
# 1245		died
#
# 1246		survived
#
# 1247		died
#
# 1248		survived
#
# 1249		died
#
# 1250		died
#
# 1251		survived
#
# 1252		died
#
# 1253		survived
#
# 1254		survived
#
# 1255		died
#
# 1256		survived
#
# 1257		survived
#
# 1258		died
#
# 1259		survived
#
# 1260		survived
#
# 1261		died
#
# 1262		died
#
# 1263		survived
#
# 1264		died
#
# 1265		died
#
# 1266		survived
#
# 1267		survived
#
# 1268		survived
#
# 1269		died
#
# 1270		died
#
# 1271		died
#
# 1272		died
#
# 1273		died
#
# 1274		survived
#
# 1275		survived
#
# 1276		died
#
# 1277		survived
#
# 1278		died
#
# 1279		died
#
# 1280		died
#
# 1281		died
#
# 1282		died
#
# 1283		survived
#
# 1284		died
#
# 1285		died
#
# 1286		died
#
# 1287		survived
#
# 1288		died
#
# 1289		survived
#
# 1290		died
#
# 1291		died
#
# 1292		survived
#
# 1293		died
#
# 1294		survived
#
# 1295		died
#
# 1296		died
#
# 1297		died
#
# 1298		died
#
# 1299		survived
#
# 1300		survived
#
# 1301		survived
#
# 1302		survived
#
# 1303		survived
#
# 1304		survived
#
# 1305		died
#
# 1306		survived
#
# 1307		died
#
# 1308		died
#
# 1309		died

# %%
print('done!')
# Out:
# done!

# %% [markdown]
# Links úteis
# - **Pandas: powerful Python data analysis toolkit**. Disponível em http://pandas.pydata.org/pandas-docs/stable/
# - **Jupyter**. Disponível em http://jupyter.org/
# - **Anaconda: The Most Popular Python Data Science Platform**. Disponível em https://www.anaconda.com/what-is-anaconda/
